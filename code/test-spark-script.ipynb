# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('../data/train.csv')
train_v1 = pd.read_csv('../data/train_v1.csv')

# %%
train.head()
# Out:
#    genre_id   ts_listen  media_id  album_id  context_type  release_date  \
# 0     25471  1480597215    222606     41774            12      20040704
# 1     25571  1480544735    250467     43941             0      20060301
# 2        16  1479563953    305197     48078             1      20140714
# 3         7  1480152098    900502     71521             0      20001030
# 4         7  1478368974    542335     71718             0      20080215
#
#    platform_name  platform_family  media_duration  listen_type  user_gender  \
# 0              1                0             223            0            0
# 1              2                1             171            0            0
# 2              2                1             149            1            1
# 3              0                0             240            0            1
# 4              0                0             150            0            1
#
#    user_id  artist_id  user_age  is_listened
# ...

# %%
groups = train_v1.groupby(['media_id', 'user_id'])

# %%
groups.groups
# Out:
# {(562487, 4755): Int64Index([3531323], dtype='int64'),
#  (126866297,
#   132): Int64Index([3278939, 3278940, 3278941, 3278942, 3278943, 3278944, 3278945,
#              3278946, 3278947, 3278948],
#             dtype='int64'),
#  (2252935, 4545): Int64Index([1957326], dtype='int64'),
#  (1143637,
#   502): Int64Index([5114185, 5114186, 5114187, 5114188, 5114189, 5114190, 5114191,
#              5114192, 5114193, 5114194, 5114195, 5114196, 5114197, 5114198,
#              5114199, 5114200],
#             dtype='int64'),
#  (113366544, 7646): Int64Index([1801737], dtype='int64'),
#  (13243323, 4242): Int64Index([5101200, 5101201, 5101202], dtype='int64'),
#  (66744159, 7258): Int64Index([5918912], dtype='int64'),
#  (869545, 2379): Int64Index([4386295], dtype='int64'),
#  (117585774, 8096): Int64Index([32309], dtype='int64'),
#  (100889634, 7321): Int64Index([1448456], dtype='int64'),
#  (135373516, 15824): Int64Index([4188029], dtype='int64'),
# ...

# %%
for key, df in groups:
    if key == (1143637, 502):
        found = df
        print('found')
        break
# Out:
# found

# %%
df = df.sort_values(by='ts_listen')

# %%
df['test_ts_listen'] = df.ts_listen.rolling(window=2).apply(lambda x: x[1]-x[0])
